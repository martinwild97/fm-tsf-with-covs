# %%
import sys
import os
import ast
import requests
# Compute the project root directory (adjust the number of ".." as needed)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
# curl -X GET "https://ai.prognostica.de/models/forecasting/model" -H "Authorization: Bearer $PROGAI_TOKEN"
response = requests.get(
    "https://ai.prognostica.de/models/forecasting/model",
    headers={"Authorization": f"Bearer {os.environ['PROGAI_TOKEN']}"}
)
print(response.status_code)
print(response.text)
# Out:
# 200
# {"model_type":"timesfm","model_path":"google/timesfm-2.0-500m-pytorch","model_kwargs":{"backend":"gpu"}}

# %%
# curl -POST "https://ai.prognostica.de/models/forecasting/model/" \
#   -H "Content-Type: application/json" \
#   -H "Authorization: Bearer $PROGAI_TOKEN" \
#   -d '{"model_type": "ttm", "model_path": "ibm-granite/granite-timeseries-ttm-r2"}'
response = requests.post(
    "https://ai.prognostica.de/models/forecasting/model",
    headers={
        "Content-Type": "application/json",
        "Authorization": f"Bearer {os.environ['PROGAI_TOKEN']}"
    },
    json={
        "model_type": "ttm",
        # "model_path": "ibm-granite/granite-timeseries-ttm-r2"
    }
)
print(response.status_code)
print(response.text)
# Out:
# 200
# {"status":"Active model updated to 'ttm' with path: ibm-granite/granite-timeseries-ttm-r2 and parameters: {}"}

# %%
# curl "https://ai.prognostica.de/models/forecasting/forecast" \
#   -H "Content-Type: application/json" \
#   -H "Authorization: Bearer $PROGAI_TOKEN" \
#   -d '{"forecast_horizon": 3, "actuals":{"timestamp": ["2024-01-01", "2024-02-01", "2024-03-01", "2024-04-01", "2024-05-01"], "data":{ "value": [1, 2, 3, 4, 5]}, "frequency": "M", "timestamp_format": "%Y-%m-%d"}}'
response = requests.post(
    "https://ai.prognostica.de/models/forecasting/forecast",
    headers={
        "Content-Type": "application/json",
        "Authorization": f"Bearer {os.environ['PROGAI_TOKEN']}"
    },
    json={
        "forecast_horizon": 3,
        "actuals": {
            "timestamp": [
                "2024-01-01",
                "2024-02-01",
                "2024-03-01",
                "2024-04-01",
                "2024-05-01"
            ],
            "data": {
                "value": [1, 2, 3, 4, 5]
            },
            "frequency": "M",
            "timestamp_format": "%Y-%m-%d"
        }
    }
)
print(response.status_code)
print(response.text)
# Out:
# 200
# {"timestamp":["2024-06-01 00:00:00","2024-07-01 00:00:00","2024-08-01 00:00:00"],"data":{"value":[3.736410617828369,3.3039259910583496,4.473542213439941]},"lower":{"value":[2.3564870357513428,-3.9537487030029297,-0.8594257831573486]},"upper":{"value":[8.690813064575195,11.737666130065918,11.539649963378906]},"metadata":{"model":"Salesforce/moirai-moe-1.0-R-small","forecast_time_seconds":7.62939453125e-05,"model_kwargs":{}}}
